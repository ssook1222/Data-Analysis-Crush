# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/Data-Analysis-Crush/blob/main/1%ED%9A%8C%EB%8F%85/2%EC%98%81%EC%97%AD/fraud_company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/audit/x_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/audit/y_train.csv")
x_test = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/audit/x_test.csv")
y_test = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/audit/y_test.csv")

# %%
print(x_train.isna().sum())
print(x_test.isna().sum())
# Out:
# ID                0
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       1
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# dtype: int64
# ID                0
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       1
# Score_MV          0
# Risk_D            0
# District_Loss     0
# ...

# %%
x_train = x_train.fillna(x_train.mode().iloc[0])
x_test = x_test.fillna(x_test.mode().iloc[0])

# %%
print(x_train.isna().sum())
print(x_test.isna().sum())
# Out:
# ID                0
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       0
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# dtype: int64
# ID                0
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       0
# Score_MV          0
# Risk_D            0
# District_Loss     0
# ...

# %%
print(x_train.info())
print(x_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              620 non-null    int64
#  1   Sector_score    620 non-null    float64
#  2   LOCATION_ID     620 non-null    object
#  3   PARA_A          620 non-null    float64
#  4   Score_A         620 non-null    float64
#  5   Risk_A          620 non-null    float64
#  6   PARA_B          620 non-null    float64
#  7   Score_B         620 non-null    float64
#  8   Risk_B          620 non-null    float64
#  9   TOTAL           620 non-null    float64
#  10  numbers         620 non-null    float64
#  11  Score_B.1       620 non-null    float64
#  12  Risk_C          620 non-null    float64
#  13  Money_Value     620 non-null    float64
#  14  Score_MV        620 non-null    float64
#  15  Risk_D          620 non-null    float64
#  16  District_Loss   620 non-null    int64
# ...

# %%
cols = x_train.select_dtypes(include="object")

for col in cols:
  le = LabelEncoder()
  x_train[col] = le.fit_transform(x_train[col])
  x_test[col] = le.transform(x_test[col])

# %%
min_max_scaler = MinMaxScaler()
x_train_data = min_max_scaler.fit_transform(x_train)
x_test_data = min_max_scaler.transform(x_test)

x_train = pd.DataFrame(x_train_data, columns = x_train.columns)
x_test = pd.DataFrame(x_test_data, columns = x_test.columns)

# %%
rfc = RandomForestClassifier(n_estimators = 2, max_depth = 2)
model = rfc.fit(x_train, y_train)
predict = model.predict(x_test)

# %%
print(accuracy_score(y_test['Risk'], predict[:,1]))
# Out:
# 1.0

# %%
submit = pd.DataFrame(data = predict, columns = y_test.columns)
submit.head(5)
# Out:
#     ID  Risk
# 0  664     1
# 1  664     1
# 2  664     0
# 3   15     0
# 4   15     0
