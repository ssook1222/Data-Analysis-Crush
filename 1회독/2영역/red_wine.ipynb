# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/Data-Analysis-Crush/blob/main/1%ED%9A%8C%EB%8F%85/2%EC%98%81%EC%97%AD/red_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

# %%
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/redwine/x_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/redwine/y_train.csv")
x_test = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/redwine/x_test.csv")
y_test = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/redwine/y_test.csv")

# %%
print(x_train.isna().sum())
print(x_test.isna().sum())

print(x_train.info())
print(x_test.info())

cols = x_train.select_dtypes(include = object)

le = LabelEncoder()

for col in cols:
  x_train[col] = le.fit_transform(x_train[col])
  x_test[col] = le.transform(x_test[col])

min_max = MinMaxScaler()

x_train_data = min_max.fit_transform(x_train)
x_test_data = min_max.transform(x_test)

x_train = pd.DataFrame(x_train_data, columns = x_train.columns)
x_test = pd.DataFrame(x_test_data, columns = x_test.columns)

dtr = DecisionTreeRegressor(random_state = 42)
model = dtr.fit(x_train, y_train)
predict = model.predict(x_test)
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1279 entries, 0 to 1278
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1279 non-null   int64
# ...

# %%
y_test
# Out:
#        ID  quality
# 0       0        6
# 1       7        6
# 2      12        5
# 3      13        3
# 4      25        6
# ..    ...      ...
# 315  1587        5
# 316  1589        6
# 317  1591        5
# 318  1592        5
# 319  1595        7
#
# [320 rows x 2 columns]

# %%
print(mean_absolute_error(y_test['quality'], predict[:, 1]))
# Out:
# 0.7375

# %%
submit = y_test
submit['quality'] = predict[:, 1]
submit
# Out:
#        ID  quality
# 0       0      6.0
# 1       7      5.0
# 2      12      6.0
# 3      13      5.0
# 4      25      8.0
# ..    ...      ...
# 315  1587      6.0
# 316  1589      5.0
# 317  1591      6.0
# 318  1592      4.0
# 319  1595      4.0
#
# [320 rows x 2 columns]
