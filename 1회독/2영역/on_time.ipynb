# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/Data-Analysis-Crush/blob/main/1%ED%9A%8C%EB%8F%85/2%EC%98%81%EC%97%AD/on_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 정시 배송 여부 판단

# %% [markdown]
# ## 라이브러리 가져오기

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 데이터 불러오기

# %%
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_train.csv")
x_test = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_test.csv")
y_test = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_test.csv")

# %% [markdown]
# ## 데이터 전처리하기

# %% [markdown]
# ### 데이터 결측치 확인

# %%
x_test.isna().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# dtype: int64

# %% [markdown]
# ### 데이터 타입 확인

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6598 entries, 0 to 6597
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6598 non-null   int64
#  1   Warehouse_block      6598 non-null   object
#  2   Mode_of_Shipment     6598 non-null   object
#  3   Customer_care_calls  6598 non-null   object
#  4   Customer_rating      6598 non-null   int64
#  5   Cost_of_the_Product  6598 non-null   int64
#  6   Prior_purchases      6598 non-null   int64
#  7   Product_importance   6598 non-null   object
#  8   Gender               6598 non-null   object
#  9   Discount_offered     6598 non-null   int64
#  10  Weight_in_gms        6598 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 567.1+ KB

# %%
cols = list(x_test.select_dtypes('object'))
le = LabelEncoder()

for col in cols:
  x_test[col] = le.fit_transform(x_test[col])
  x_train[col] = le.fit_transform(x_train[col])

# %% [markdown]
# ### 데이터 스케일링

# %%
MinMax = MinMaxScaler()

x_train_data = MinMax.fit_transform(x_train)
x_test_data = MinMax.fit_transform(x_test)

x_train = pd.DataFrame(columns = x_train.columns, data = x_train_data)
x_test = pd.DataFrame(columns = x_test.columns, data = x_test_data)

# %% [markdown]
# ### 데이터 분석 진행

# %%
rfc = RandomForestClassifier(n_estimators = 3, max_depth = 3)
model = rfc.fit(x_train, y_train)
predict = model.predict(x_test)

# %% [markdown]
# ### 정확도 확인

# %%
y_test
# Out:
#          ID  Reached.on.Time_Y.N
# 0      6811                    0
# 1      4320                    0
# 2      5732                    1
# 3      7429                    0
# 4      2191                    1
# ...     ...                  ...
# 4396   2610                    1
# 4397   3406                    0
# 4398  10395                    1
# 4399   3646                    1
# 4400    573                    1
#
# [4401 rows x 2 columns]

# %%
print(accuracy_score(predict[:,1], y_test['Reached.on.Time_Y.N']))
# Out:
# 0.6814360372642582

# %%
submit = pd.DataFrame(columns = y_test.columns, data = predict)

# %%
display(submit)
# Out:
#          ID  Reached.on.Time_Y.N
# 0      7462                    0
# 1      3762                    0
# 2      5224                    0
# 3      4258                    0
# 4       620                    1
# ...     ...                  ...
# 4396    620                    1
# 4397   3384                    0
# 4398  10318                    0
# 4399   3644                    1
# 4400    620                    1
#
# [4401 rows x 2 columns]
